# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # New Section

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d siranjeevivece6039/global-sales
# Out:
# ...
#   0% 0.00/3.48M [00:00<?, ?B/s]
# 100% 3.48M/3.48M [00:00<00:00, 190MB/s]

# %%
! unzip global-sales
# Out:
# Archive:  global-sales.zip
# replace Global.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('Global.csv')

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                               .072  \
# 1970  MX-2011-111255  04-01-2011 09-01-2011 Second Class   RA-19915 Russell Applegate  Consumer    Francisco Beltrão Parana            Brazil        NaN     LATAM South      OFF-SU-10003629 Office Supplies Supplies   Fiskars Letter Opener, Easy Grip                   148.960 8 0.0  28.1600
# 4282  MX-2013-105753  10-09-2013 15-09-2013 Second Class   MH-17785 Maya Herman        Corporate   Tlalnepantla      México            Mexico        NaN     LATAM North      OFF-LA-10004747 Office Supplies Labels     Hon Color Coded Labels, Alphabetical               75.780  9 0.0  36.3600
# ...
